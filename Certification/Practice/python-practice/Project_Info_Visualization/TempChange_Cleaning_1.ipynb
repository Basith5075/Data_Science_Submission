# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Temperature_Change_Data.csv',encoding='latin-1')
df_countryCode = pd.read_csv('FAOSTAT_data_11-24-2020.csv')

# %%
display(df.head(5))

print("Months")

df.Months.unique()

print('Elements')

df.Element.unique()

df_countryCode.head(10)
# Out:
#    Area Code Area Code (M49)         Area  Months Code    Months  \
# 0          2            '004  Afghanistan         7001   January
# 1          2            '004  Afghanistan         7001   January
# 2          2            '004  Afghanistan         7002  February
# 3          2            '004  Afghanistan         7002  February
# 4          2            '004  Afghanistan         7003     March
#
#    Element Code             Element Unit  Y1961 Y1961F  ...  Y2017 Y2017F  \
# 0          7271  Temperature change   °C  0.786      E  ...  1.273      E
# 1          6078  Standard Deviation   °C  1.944      E  ...  1.944      E
# 2          7271  Temperature change   °C -1.762      E  ... -0.189      E
# 3          6078  Standard Deviation   °C  2.603      E  ...  2.603      E
# 4          7271  Temperature change   °C  0.477      E  ...  0.923      E
#
#    Y2018 Y2018F  Y2019 Y2019F  Y2020 Y2020F  Y2021 Y2021F
# 0  2.127      E  2.978      E -0.584      E  0.558      E
# ...

# %%
# Renaming the columns
df.rename(columns={'Area':'Country_Name'},inplace=True)

# Used for removing the by default index

#df.set_index('Country_Name')

#df.reset_index(inplace = True)

#df.set_index('Months',inplace=True)
#df.reset_index(inplace = True)
df = df[df ['Element']=='Temperature change']
df = df [df['Months']=='Meteorological year']
display(df.head(50))
# Out:
#       Area Code Area Code (M49)                      Country_Name  \
# 32            2            '004                       Afghanistan
# 66            3            '008                           Albania
# 100           4            '012                           Algeria
# 134           5            '016                    American Samoa
# 168           6            '020                           Andorra
# 202           7            '024                            Angola
# 236         258            '660                          Anguilla
# 270          30            '010                        Antarctica
# 304           8            '028               Antigua and Barbuda
# 338           9            '032                         Argentina
# 372           1            '051                           Armenia
# 406          22            '533                             Aruba
# 440          10            '036                         Australia
# ...

# %%
# drop unwanted columns from df

#df_countryCode.drop(['Country Code','M49 Code','ISO2 Code','Start Year','End Year'],axis=1,inplace=True)
display(df_countryCode)
df_countryCode.rename(columns={'Country':'Country_Name','ISO3 Code':'Country_Code'},inplace=True)
display(df_countryCode)
# Out:
#      Country Code        Country  M49 Code ISO2 Code ISO3 Code  Start Year  \
# 0               2    Afghanistan       4.0        AF       AFG         NaN
# 1            5100         Africa       2.0       NaN       X06         NaN
# 2             284  Åland Islands     248.0       NaN       ALA         NaN
# 3               3        Albania       8.0        AL       ALB         NaN
# 4               4        Algeria      12.0        DZ       DZA         NaN
# ..            ...            ...       ...       ...       ...         ...
# 316           246    Yemen Ar Rp     886.0       NaN       NaN         NaN
# 317           247      Yemen Dem     720.0       NaN       NaN         NaN
# 318           248   Yugoslav SFR     890.0       NaN       NaN         NaN
# 319           251         Zambia     894.0        ZM       ZMB         NaN
# 320           181       Zimbabwe     716.0        ZW       ZWE         NaN
#
#      End Year
# 0         NaN
# 1         NaN
# 2         NaN
# ...

# %%
df = pd.merge(df,df_countryCode,how = 'outer',on='Country_Name')

display(df.head(10))
df.to_csv('E:\Output.csv')
# Out:
#    Area Code Area Code (M49)         Country_Name  Months Code  \
# 0        2.0            '004          Afghanistan       7020.0
# 1        3.0            '008              Albania       7020.0
# 2        4.0            '012              Algeria       7020.0
# 3        5.0            '016       American Samoa       7020.0
# 4        6.0            '020              Andorra       7020.0
# 5        7.0            '024               Angola       7020.0
# 6      258.0            '660             Anguilla       7020.0
# 7       30.0            '010           Antarctica       7020.0
# 8        8.0            '028  Antigua and Barbuda       7020.0
# 9        9.0            '032            Argentina       7020.0
#
#                 Months  Element Code             Element Unit  Y1961 Y1961F  \
# 0  Meteorological year        7271.0  Temperature change   °C -0.105      E
# 1  Meteorological year        7271.0  Temperature change   °C  0.627      E
# ...

# %%
year_list = []

for n in range(1961,2022):
    year = 'Y'+str(n)+'F'
    year_list.append(year)

#year_list

#df.drop(year_list,axis=1,inplace=True)

#df.to_csv('E:\Output1.csv')
display(df)

columns_deleted = ['Area Code','Area Code (M49)','Months Code','Months','Unit','Element Code','Element','Country Code','M49 Code','ISO2 Code','Start Year', 'End Year']


df.drop(columns_deleted,axis = 1, inplace=True) 
df
# Out:
#      Area Code Area Code (M49)                          Country_Name  \
# 0          2.0            '004                           Afghanistan
# 1          3.0            '008                               Albania
# 2          4.0            '012                               Algeria
# 3          5.0            '016                        American Samoa
# 4          6.0            '020                               Andorra
# ..         ...             ...                                   ...
# 317        NaN             NaN  United States Minor Outlying Islands
# 318        NaN             NaN         Upper-middle-income economies
# 319        NaN             NaN      Western Asia and Northern Africa
# 320        NaN             NaN                           Yemen Ar Rp
# 321        NaN             NaN                             Yemen Dem
#
#      Months Code               Months  Element Code             Element Unit  \
# ...

# %%
df.head(10)
#df.drop(['Area Code','Months Code','Element Code','Element','Unit'],axis=1,inplace=True)
df.head(10)
df = df.melt(id_vars=["Country_Code", "Country_Name","Months"], var_name="year", value_name="tem_change")
df["year"] = [i.split("Y")[-1] for i in df.year]

display(df.head(35))

# %%
df.set_index('Country_Code')
df.to_csv('E:\Final.csv')

# %%
df
# Out:
#       Country_Code                          Country_Name               Months  \
# 0              AFG                           Afghanistan  Meteorological year
# 1              ALB                               Albania  Meteorological year
# 2              DZA                               Algeria  Meteorological year
# 3              ASM                        American Samoa  Meteorological year
# 4              AND                               Andorra  Meteorological year
# ...            ...                                   ...                  ...
# 85647          UMI  United States Minor Outlying Islands                  NaN
# 85648          NaN         Upper-middle-income economies                  NaN
# 85649          NaN      Western Asia and Northern Africa                  NaN
# 85650          NaN                           Yemen Ar Rp                  NaN
# 85651          NaN                             Yemen Dem                  NaN
#
#              year tem_change
# ...
