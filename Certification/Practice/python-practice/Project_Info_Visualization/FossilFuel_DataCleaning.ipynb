# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Fossil_Fuel_Data.csv',skiprows=4)

# %%
display(df.head(10))

df.drop({'Indicator Name','Indicator Code'},axis=1,inplace=True)
df
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
# 5                      Albania          ALB
# 6                      Andorra          AND
# 7                   Arab World          ARB
# 8         United Arab Emirates          ARE
# 9                    Argentina          ARG
#
#                                 Indicator Name     Indicator Code  1960  1961  \
# 0  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
# 1  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
# 2  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
# 3  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
# 4  Fossil fuel energy consumption (% of total)  EG.USE.COMM.FO.ZS   NaN   NaN
# ...

# %%
df.set_index('Country Name')
year_del = []
for n in range(1961,1981):
    year_del.append(str(n))
#df.drop(year_del,axis = 1, inplace=True)

df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 5>()
#       3 for n in range(1961,1981):
#       4     year_del.append(str(n))
# ----> 5 df.drop(year_del,axis = 1, inplace=True)
#       7 df
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
display(df.head(50))
df.to_csv('E:\Fossil_Final.csv')
# Out:
#                       Country Name Country Code       1981       1982  \
# 0                            Aruba          ABW        NaN        NaN
# 1      Africa Eastern and Southern          AFE  51.342579  52.578118
# 2                      Afghanistan          AFG        NaN        NaN
# 3       Africa Western and Central          AFW  21.991861  23.180888
# 4                           Angola          AGO  19.159395  16.616550
# 5                          Albania          ALB  78.037910  77.836534
# 6                          Andorra          AND        NaN        NaN
# 7                       Arab World          ARB  91.573704  92.244831
# 8             United Arab Emirates          ARE        NaN        NaN
# 9                        Argentina          ARG  90.017182  90.445184
# 10                         Armenia          ARM        NaN        NaN
# 11                  American Samoa          ASM        NaN        NaN
# ...
